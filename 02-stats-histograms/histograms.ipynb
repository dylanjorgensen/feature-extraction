# %% [markdown]
# # Histograms

# %%
import pandas as pd

df = pd.read_csv("sysco.csv")

df.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  12669  9656     7561     214              2674          1338
# 1   7057  9810     9568    1762              3293          1776
# 2   6353  8808     7684    2405              3516          7844
# 3  13265  1196     4221    6404               507          1788
# 4  22615  5410     7198    3915              1777          5185

# %% [markdown]
# ### = Import mpltools...

# %%
import numpy as np
import matplotlib.pyplot as plt

from mpltools import style
from mpltools import layout

style.use('ggplot')

# %% [markdown]
# ### = Single Hist...

# %%
# %matplotlib inline

df['Grocery'].hist(alpha=0.5)

# %% [markdown]
# ### = Column Interation Hists...

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11dfb6e10>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11f1b9990>]], dtype=object)
